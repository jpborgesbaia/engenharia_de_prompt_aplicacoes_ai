# %% [markdown]
# <a href="https://colab.research.google.com/github/jpborgesbaia/engenharia_de_prompt_aplicacoes_ai/blob/main/aula07_Programa%C3%A7%C3%A3oAssistida.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Aula: Programação Assistida
#
# Nome: João Pedro Baía (Turma de Sexta)

# %%
# Define uma lista de números inteiros
numeros = [1, 3, 6, 7, 8]

# Inicializa uma variável para armazenar a soma dos números
soma = 0

# Itera
for num in numeros:
  soma += num
print(soma)
# Out:
# 25
